# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("bodyfat.csv")

# %%
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
df.corr()
# Out:
#           Density   BodyFat       Age    Weight    Height      Neck     Chest  \
# Density  1.000000 -0.987782 -0.277637 -0.594062  0.097881 -0.472966 -0.682599
# BodyFat -0.987782  1.000000  0.291458  0.612414 -0.089495  0.490592  0.702620
# Age     -0.277637  0.291458  1.000000 -0.012746 -0.171645  0.113505  0.176450
# Weight  -0.594062  0.612414 -0.012746  1.000000  0.308279  0.830716  0.894191
# Height   0.097881 -0.089495 -0.171645  0.308279  1.000000  0.253710  0.134892
# Neck    -0.472966  0.490592  0.113505  0.830716  0.253710  1.000000  0.784835
# Chest   -0.682599  0.702620  0.176450  0.894191  0.134892  0.784835  1.000000
# Abdomen -0.798955  0.813432  0.230409  0.887995  0.087813  0.754077  0.915828
# Hip     -0.609331  0.625201 -0.050332  0.940884  0.170394  0.734958  0.829420
# Thigh   -0.553091  0.559608 -0.200096  0.868694  0.148436  0.695697  0.729859
# Knee    -0.495040  0.508665  0.017516  0.853167  0.286053  0.672405  0.719496
# ...

# %%
df['BodyFat'].corr
# Out:
# <bound method Series.corr of 0      12.3
# 1       6.1
# 2      25.3
# 3      10.4
# 4      28.7
#        ...
# 247    11.0
# 248    33.6
# 249    29.3
# 250    26.0
# 251    31.9
# Name: BodyFat, Length: 252, dtype: float64>

# %%
df.describe()
# Out:
#           Density     BodyFat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.150794   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368740   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# ...

# %%
df.shape
# Out:
# (252, 15)

# %%
df.isnull().sum()
# Out:
# Density    0
# BodyFat    0
# Age        0
# Weight     0
# Height     0
# Neck       0
# Chest      0
# Abdomen    0
# Hip        0
# Thigh      0
# Knee       0
# Ankle      0
# Biceps     0
# Forearm    0
# Wrist      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop('Density',inplace=True,axis=1)

# %%
y=df['BodyFat']
y
# Out:
# 0      12.3
# 1       6.1
# 2      25.3
# 3      10.4
# 4      28.7
#        ...
# 247    11.0
# 248    33.6
# 249    29.3
# 250    26.0
# 251    31.9
# Name: BodyFat, Length: 252, dtype: float64

# %%
df.drop('BodyFat',inplace=True,axis=1)

# %%
df
# Out:
#      Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0     23  154.25   67.75  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1     22  173.25   72.25  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2     22  154.00   66.25  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3     26  184.75   72.25  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4     24  184.25   71.25  34.4   97.3    100.0  101.9   63.2  42.2   24.0
# ..   ...     ...     ...   ...    ...      ...    ...    ...   ...    ...
# 247   70  134.25   67.00  34.9   89.2     83.6   88.8   49.6  34.8   21.5
# 248   72  201.00   69.75  40.9  108.5    105.0  104.5   59.6  40.8   23.2
# 249   72  186.75   66.00  38.9  111.1    111.5  101.7   60.3  37.3   21.5
# 250   72  190.75   70.50  38.9  108.3    101.3   97.8   56.0  41.6   22.7
# 251   74  207.50   70.00  40.8  112.4    108.5  107.1   59.3  42.2   24.6
#
#      Biceps  Forearm  Wrist
# 0      32.0     27.4   17.1
# ...

# %%
y
# Out:
# 0      12.3
# 1       6.1
# 2      25.3
# 3      10.4
# 4      28.7
#        ...
# 247    11.0
# 248    33.6
# 249    29.3
# 250    26.0
# 251    31.9
# Name: BodyFat, Length: 252, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
lnr=LinearRegression()
lnr
# Out:
# LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(df,y,random_state=42)

# %%
x_train.shape
# Out:
# (189, 13)

# %%
x_test
# Out:
#      Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 165   35  217.00   73.75  40.5  107.5     95.1  104.5   64.8  41.3   25.6
# 6     26  181.00   69.75  36.4  105.1     90.7  100.3   58.4  38.3   22.9
# 111   43  183.25   70.00  37.1  108.0    105.0  103.0   63.7  40.0   23.6
# 172   35  177.25   71.00  38.4  100.5     90.3   98.7   57.8  37.3   22.4
# 115   40  158.00   69.25  36.3   97.0     86.6   92.6   55.9  36.3   22.1
# ..   ...     ...     ...   ...    ...      ...    ...    ...   ...    ...
# 193   42  224.75   74.75  38.5  106.7    105.7  111.8   65.3  43.3   26.0
# 249   72  186.75   66.00  38.9  111.1    111.5  101.7   60.3  37.3   21.5
# 170   35  152.25   67.75  37.0   92.2     81.9   92.8   54.7  36.2   22.1
# 126   42  177.50   68.75  38.9   98.7     92.1   98.5   60.7  36.8   22.2
# 97    50  162.50   66.50  38.7   99.4     86.7   96.2   62.1  39.3   23.3
#
#      Biceps  Forearm  Wrist
# 165    36.4     33.7   19.4
# ...

# %%
lnr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lnr.predict(x_test)
y_pred=list(y_pred)

# %%
y_test=list(y_test)

# %%
lnr.score(x_train,y_train)
# Out:
# 0.7659030258644988

# %%
lnr.score(x_test,y_test)
# Out:
# 0.6386850093128672

# %%
lnr.score(x_test,y_pred)
# Out:
# 1.0

# %%
x_test
# Out:
#      Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 165   35  217.00   73.75  40.5  107.5     95.1  104.5   64.8  41.3   25.6
# 6     26  181.00   69.75  36.4  105.1     90.7  100.3   58.4  38.3   22.9
# 111   43  183.25   70.00  37.1  108.0    105.0  103.0   63.7  40.0   23.6
# 172   35  177.25   71.00  38.4  100.5     90.3   98.7   57.8  37.3   22.4
# 115   40  158.00   69.25  36.3   97.0     86.6   92.6   55.9  36.3   22.1
# ..   ...     ...     ...   ...    ...      ...    ...    ...   ...    ...
# 193   42  224.75   74.75  38.5  106.7    105.7  111.8   65.3  43.3   26.0
# 249   72  186.75   66.00  38.9  111.1    111.5  101.7   60.3  37.3   21.5
# 170   35  152.25   67.75  37.0   92.2     81.9   92.8   54.7  36.2   22.1
# 126   42  177.50   68.75  38.9   98.7     92.1   98.5   60.7  36.8   22.2
# 97    50  162.50   66.50  38.7   99.4     86.7   96.2   62.1  39.3   23.3
#
#      Biceps  Forearm  Wrist
# 165    36.4     33.7   19.4
# ...

# %%
import os,joblib,shutil

# %%
path='./model'

# %%
if os.path.exists(path):
        shutil.rmtree(path)  # Deletes the directory and all its contents
        print(f"Directory '{path}' already existed and was removed.")
    
os.makedirs(path)  # Creates a new empty directory
print(f"Directory '{path}' has been created.")
# Out:
# Directory './model' already existed and was removed.
# Directory './model' has been created.

# %%
joblib.dump(lnr,"./model/linear_regression.lb")
# Out:
# ['./model/linear_regression.lb']
